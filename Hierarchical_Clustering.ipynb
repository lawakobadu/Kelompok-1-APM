# %% [markdown]
# <a href="https://colab.research.google.com/github/lawakobadu/Kelompok-1-APM/blob/main/Hierarchical_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np

# %%
data = pd.read_csv("Cust.csv")
data
# Out:
#       ID Gender_Code Region  Income  Spending
# 0      1      Female  Rural      20        15
# 1      2        Male  Rural       5        12
# 2      3      Female  Urban      28        18
# 3      4        Male  Urban      40        10
# 4      5        Male  Urban      42         9
# ..   ...         ...    ...     ...       ...
# 195  196        Male  Urban      47        13
# 196  197        Male  Urban      39        15
# 197  198      Female  Rural      15        20
# 198  199        Male  Rural      25         7
# 199  200        Male  Urban      28        18
#
# [200 rows x 5 columns]

# %%
X = data.iloc[:, 3:5].values

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(X, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=7, affinity='euclidean', linkage='ward')
cluster.fit_predict(X)
# Out:
# array([3, 0, 4, 2, 2, 3, 5, 0, 6, 3, 0, 5, 2, 5, 0, 1, 5, 3, 2, 0, 6, 3,
#        4, 2, 3, 3, 0, 6, 1, 3, 5, 6, 1, 0, 3, 3, 6, 0, 4, 4, 0, 3, 2, 4,
#        3, 5, 1, 0, 2, 5, 6, 0, 4, 2, 5, 2, 3, 6, 5, 2, 2, 0, 3, 5, 3, 0,
#        0, 6, 6, 5, 0, 0, 6, 1, 0, 1, 5, 0, 0, 1, 0, 0, 6, 5, 6, 1, 2, 6,
#        5, 2, 4, 3, 3, 0, 4, 6, 6, 6, 0, 2, 3, 0, 0, 2, 3, 2, 0, 0, 2, 4,
#        4, 6, 6, 5, 4, 6, 6, 4, 1, 2, 3, 0, 0, 0, 0, 5, 6, 1, 0, 1, 2, 6,
#        5, 6, 5, 2, 1, 0, 5, 0, 0, 5, 1, 5, 4, 6, 6, 0, 5, 0, 6, 0, 1, 2,
#        1, 0, 4, 3, 2, 3, 0, 0, 6, 0, 4, 5, 2, 2, 1, 6, 3, 0, 0, 1, 2, 6,
#        5, 5, 1, 3, 1, 6, 6, 6, 5, 1, 1, 5, 6, 0, 5, 0, 0, 0, 4, 1, 1, 3,
#        6, 4])

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X[:,0], X[:,1], c=cluster.labels_, cmap='rainbow')
plt.title('Clusters Customer')
plt.xlabel('Income (million/month)')
plt.ylabel('Spending( million/month)')
plt.show()
