# %% [markdown]
# <a href="https://colab.research.google.com/github/lawakobadu/Kelompok-1-APM/blob/main/Eclat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mengimpor library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Mengimpor dataset
dataset = pd.read_csv('optimisasi_retail.csv', header = None )
jumlah_baris = dataset.shape[0]
jumlah_kolom = dataset.shape[1]
transaksi = [[str(dataset.values[i,j]) for j in range(0, jumlah_kolom) if str(dataset.values[i,j])!='nan']
                                              for i in range(0, jumlah_baris)]
transaksi
# Out:
# [['udang',
#   'almond',
#   'alpukat',
#   'sayuran',
#   'anggur hijau',
#   'gandum',
#   'ragi',
#   'keju kemasan',
#   'minuman berenergi',
#   'jus tomat',
#   'susu yogurt',
#   'teh hijau',
#   'madu',
#   'salad',
#   'air mineral',
#   'salmon',
#   'minuman bervitamin',
#   'minuman rasa',
#   'bayam',
#   'minyak zaitun'],
#  ['burger', 'bakso', 'telur'],
#  ['kacang mete'],
#  ['bebek', 'alpukat'],
#  ['air mineral', 'susu', 'snack batangan', 'tepung beras', 'teh hijau'],
#  ['susu yogurt'],
#  ['pasta gandum', 'kentang goreng'],
#  ['sup', 'krim ', 'bawang merah'],
#  ['sayuran beku', 'spageti', 'teh hijau'],
#  ['kentang goreng'],
#  ['telur', 'makanan binatang'],
#  ['biskuit'],
#  ['bebek', 'burger', 'air mineral', 'telur', 'minyak goreng'],
#  ['spageti', 'kecap asin', 'biskuit'],
#  ['air mineral', 'salmon'],
#  ['air mineral'],
#  ['udang',
#   'cokelat',
#   'ayam',
#   'madu',
#   'minyak',
#   'minyak goreng',
#   'susu yogurt'],
#  ['bebek', 'telur'],
#  ['bebek',
#   'tuna segar',
#   'tomat',
#   'spageti',
#   'air mineral',
#   'teh hitam',
#   'salmon',
#   'telur',
#   'ayam',
#   'cokelat hitam'],
#  ['bakso', 'susu', 'madu', 'kentang goreng', 'snack berprotein'],
#  ['saus tiram', 'udang', 'pasta', 'merica', 'telur', 'cokelat', 'sampo'],
#  ['beras', 'minuman soda'],
#  ['spageti', 'air mineral', 'daging sapi', 'deodoran', 'pancake', 'teh hijau'],
#  ['burger',
#   'keju parut',
#   'udang',
#   'pasta',
#   'alpukat',
#   'madu',
#   'minuman beralkohol',
#   'pasta gigi'],
#  ['telur'],
#  ['keju parmesan', 'spageti', 'sup', 'alpukat', 'susu', 'roti'],
#  ['daging sapi giling',
#   'spageti',
#   'air mineral',
#   'susu',
#   'snack batangan',
#   'teh hitam',
#   'salmon',
#   'minuman rasa',
#   'daging tanpa tulang'],
#  ['minuman soda'],
#  ['air mineral', 'telur', 'ayam', 'cokelat', 'kentang goreng'],
#  ['sayuran beku', 'spageti', 'ragi', 'air mineral'],
#  ['rempah-rempah', 'saus tomat', 'krim ', 'majalah'],
#  ['air mineral', 'cokelat', 'alpukat', 'telur'],
#  ['bebek', 'kentang goreng', 'stroberi'],
#  ['sayuran beku', 'keju tua', 'cokelat'],
#  ['biskuit'],
#  ['acar', 'spageti', 'salmon', 'daging tanpa tulang'],
#  ['snack batangan', 'kentang goreng'],
#  ['saus tiram', 'daging sapi giling', 'air mineral'],
#  ['air mineral', 'kue', 'keju kemasan'],
#  ['acar', 'kecap asin', 'teh hijau'],
#  ['spageti'],
#  ['tuna segar',
#   'sayuran beku',
#   'spageti',
#   'air mineral',
#   'madu',
#   'tepung beras',
#   'minuman rasa',
#   'daging tanpa tulang'],
#  ['spageti'],
#  ['sup', 'bakso', 'hotdog', 'minuman soda'],
#  ['daging tanpa tulang'],
#  ['sup',
#   'alpukat',
#   'kentang goreng',
#   'hotdog',
#   'brownis',
#   'deodoran',
#   'pancake',
#   'teh hijau'],
#  ['air mineral', 'ayam', 'sereal', 'aksesoris pakaian'],
#  ['air mineral', 'semprotan nyamuk'],
#  ['alpukat', 'muffin'],
#  ['burger', 'teh hitam', 'teh hijau'],
#  ['spageti', 'cokelat', 'brownis', 'minuman beralkohol', 'teh hijau'],
#  ['tuna segar', 'air mineral', 'telur'],
#  ['spageti', 'muffin'],
#  ['spageti', 'cokelat'],
#  ['kentang goreng', 'daging tanpa tulang', 'kecap asin'],
#  ['saus tomat', 'mayones ringan'],
#  ['bebek',
#   'tuna segar',
#   'sayuran beku',
#   'tomat',
#   'daging sapi giling',
#   'spageti',
#   'air mineral',
#   'cokelat',
#   'sup',
#   'susu',
#   'minyak zaitun'],
#  ['telur', 'biskuit'],
#  ['sup',
#   'ayam',
#   'gom arab',
#   'soda',
#   'deodoran',
#   'minuman berenergi',
#   'teh hijau'],
#  ['bebek',
#   'sayuran beku',
#   'air mineral',
#   'cider',
#   'minyak goreng',
#   'teh hijau'],
#  ['spageti'],
#  ['aksesoris pakaian'],
#  ['minuman berenergi'],
#  ['sup', 'semprotan nyamuk', 'bawang merah', 'snack berprotein', 'teh hijau'],
#  ['bebek', 'telur'],
#  ['kentang goreng'],
#  ['cokelat', 'susu'],
#  ['rempah-rempah',
#   'pasta gandum',
#   'daging sapi giling',
#   'air mineral',
#   'alpukat',
#   'cider',
#   'tepung beras'],
#  ['biskuit'],
#  ['udang', 'pasta'],
#  ['keju parut', 'rempah-rempah', 'tomat', 'saus tomat', 'corn'],
#  ['burger', 'daging tanpa tulang', 'bawang merah'],
#  ['biskuit'],
#  ['yogurt kue'],
#  ['sup', 'telur'],
#  ['biskuit'],
#  ['air mineral', 'cokelat', 'susu yogurt'],
#  ['telur', 'stroberi'],
#  ['keju parut',
#   'daging sapi giling',
#   'spageti',
#   'air mineral',
#   'minuman beralkohol'],
#  ['mint'],
#  ['telur', 'kue', 'kentang goreng'],
#  ['burger', 'spageti', 'susu', 'kentang goreng', 'teh hijau'],
#  ['air mineral', 'snack batangan', 'mentega', 'kentang goreng'],
#  ['burger',
#   'keju parut',
#   'rempah-rempah',
#   'air mineral',
#   'telur',
#   'minyak goreng'],
#  ['snack batangan'],
#  ['snack batangan', 'minuman berenergi'],
#  ['cokelat', 'minuman rasa'],
#  ['susu yogurt'],
#  ['asparagus', 'salad'],
#  ['burger', 'kentang goreng', 'susu yogurt', 'teh hijau'],
#  ['susu yogurt'],
#  ['burger',
#   'rempah-rempah',
#   'udang',
#   'pasta',
#   'spageti',
#   'air mineral',
#   'bakso',
#   'minyak zaitun',
#   'snack batangan',
#   'minyak ikan',
#   'telur',
#   'garam'],
#  ['kecap asin', 'susu yogurt'],
#  ['kecap asin'],
#  ['burger', 'almond', 'telur', 'kentang goreng', 'biskuit', 'teh hijau'],
#  ['daging sapi', 'sup', 'daging tanpa tulang', 'deodoran'],
#  ['bebek',
#   'daging sapi',
#   'sayuran beku',
#   'merica',
#   'minyak',
#   'cokelat hitam',
#   'tea',
#   'majalah'],
#  ['muffin', 'telur', 'biskuit'],
#  ['biskuit'],
#  ['sayuran beku',
#   'pasta gandum',
#   'daging sapi giling',
#   'spageti',
#   'cokelat',
#   'teh hijau'],
#  ['air mineral', 'saus BBQ', 'cokelat'],
#  ['burger',
#   'rempah-rempah',
#   'snack batangan',
#   'almond',
#   'telur',
#   'corn',
#   'mayones',
#   'laos'],
#  ['bebek',
#   'burger',
#   'daging sapi giling',
#   'cokelat',
#   'sup',
#   'almond',
#   'telur',
#   'hotdog',
#   'keju kemasan'],
#  ['daging sapi', 'spageti', 'cokelat', 'telur'],
#  ['daging sapi giling',
#   'snack batangan',
#   'makanan binatang',
#   'wortel',
#   'snack berprotein'],
#  ['daging sapi giling',
#   'saus tomat',
#   'spageti',
#   'air mineral',
#   'almond',
#   'telur'],
#  ['air mineral', 'minyak zaitun', 'gom arab', 'minyak goreng'],
#  ['udang',
#   'pasta',
#   'air mineral',
#   'sup',
#   'alpukat',
#   'susu',
#   'minyak zaitun',
#   'anggur hijau',
#   'telur',
#   'semprotan nyamuk'],
#  ['udang',
#   'pasta',
#   'sup',
#   'kue',
#   'minyak goreng',
#   'ayam',
#   'mayones ringan',
#   'susu yogurt'],
#  ['spageti',
#   'air mineral',
#   'cokelat',
#   'kentang goreng',
#   'kecap asin',
#   'daging tanpa tulang',
#   'saus krim jamur',
#   'roti'],
#  ['udang', 'pasta', 'air mineral', 'telur'],
#  ['burger', 'minyak', 'jus tomat', 'roti'],
#  ['minyak ikan', 'telur', 'cokelat', 'susu yogurt'],
#  ['ayam', 'telur', 'kentang goreng', 'pancake'],
#  ['bebek', 'rempah-rempah', 'salmon', 'minuman beralkohol', 'snack batangan'],
#  ['keju parut',
#   'spageti',
#   'minyak zaitun',
#   'telur',
#   'kentang goreng',
#   'teh hijau'],
#  ['air mineral', 'snack batangan'],
#  ['telur', 'kentang goreng'],
#  ['burger',
#   'tomat',
#   'air mineral',
#   'sup',
#   'susu',
#   'almond',
#   'telur',
#   'cokelat',
#   'jus tomat'],
#  ['muffin'],
#  ['pasta'],
#  ['tomat', 'spageti', 'minuman rasa'],
#  ['daging sapi giling', 'spageti', 'susu'],
#  ['kentang goreng'],
#  ['cokelat', 'susu'],
#  ['burger',
#   'udang',
#   'pasta',
#   'sayuran beku',
#   'spageti',
#   'air mineral',
#   'susu',
#   'telur',
#   'cokelat',
#   'kentang goreng',
#   'pancake',
#   'susu yogurt'],
#  ['daging sapi giling',
#   'air mineral',
#   'minuman bervitamin',
#   'snack berprotein'],
#  ['keju parut',
#   'pasta gandum',
#   'daging sapi giling',
#   'spageti',
#   'kue',
#   'minuman berenergi'],
#  ['keju parut'],
#  ['pancake'],
#  ['minuman rasa'],
#  ['wortel', 'teh hijau'],
#  ['cokelat'],
#  ['bebek',
#   'burger',
#   'cokelat',
#   'minyak zaitun',
#   'telur',
#   'minyak goreng',
#   'corn'],
#  ['sayuran beku',
#   'tomat',
#   'merica',
#   'spageti',
#   'air mineral',
#   'pancake',
#   'ayam',
#   'cabe',
#   'tea',
#   'kentang goreng',
#   'jus tomat',
#   'roti'],
#  ['biskuit'],
#  ['daging sapi giling'],
#  ['bebek', 'telur', 'cokelat', 'minuman rasa', 'jus tomat'],
#  ['sayuran beku', 'minyak goreng', 'kentang tumbuk'],
#  ['sayuran beku',
#   'daging sapi giling',
#   'saus tomat',
#   'air mineral',
#   'bakso',
#   'minyak zaitun',
#   'krim ',
#   'jus tomat'],
#  ['saus tiram',
#   'spageti',
#   'air mineral',
#   'sup',
#   'susu',
#   'telur',
#   'kue',
#   'gom arab',
#   'minyak goreng',
#   'cokelat',
#   'minuman rasa'],
#  ['cokelat',
#   'tomat',
#   'spageti',
#   'air mineral',
#   'alpukat',
#   'susu',
#   'minyak zaitun',
#   'telur',
#   'beras',
#   'kentang goreng',
#   'brownis'],
#  ['cokelat',
#   'udang',
#   'pasta',
#   'sayuran beku',
#   'daging sapi giling',
#   'air mineral',
#   'nonfat susu',
#   'telur'],
#  ['bebek',
#   'udang',
#   'pasta',
#   'merica',
#   'spageti',
#   'air mineral',
#   'telur',
#   'ayam',
#   'kentang goreng'],
#  ['biskuit'],
#  ['bebek', 'tomat', 'kue'],
#  ['ragi',
#   'air mineral',
#   'sup',
#   'susu',
#   'pancake',
#   'tepung beras',
#   'saus BBQ',
#   'wortel',
#   'cokelat',
#   'kecap asin'],
#  ['beras'],
#  ['cokelat', 'susu'],
#  ['udang', 'pasta', 'sayuran beku', 'semprotan air'],
#  ['burger', 'air mineral', 'susu', 'telur', 'tepung beras', 'mint'],
#  ['air mineral', 'sayuran', 'kue', 'minuman rasa', 'brownis'],
#  ['biskuit'],
#  ['udang', 'pasta', 'ayam', 'cokelat bread'],
#  ['bawang merah'],
#  ['udang', 'pasta', 'spageti', 'telur', 'hotdog', 'teh hijau'],
#  ['burger'],
#  ['saus tiram',
#   'daging sapi giling',
#   'spageti',
#   'air mineral',
#   'susu',
#   'minyak zaitun',
#   'keju tua',
#   'krim ',
#   'minyak goreng'],
#  ['burger',
#   'keju parut',
#   'spageti',
#   'alpukat',
#   'susu',
#   'minyak',
#   'kentang goreng'],
#  ['rempah-rempah',
#   'pasta gandum',
#   'daging sapi giling',
#   'air mineral',
#   'minyak zaitun'],
#  ['udang', 'pasta', 'ragi', 'susu', 'cokelat'],
#  ['mentega', 'teh hijau'],
#  ['mayones ringan'],
#  ['susu yogurt'],
#  ['rempah-rempah', 'udang', 'pasta', 'spageti', 'susu'],
#  ['burger', 'telur'],
#  ['bebek',
#   'rempah-rempah',
#   'daging sapi giling',
#   'sup',
#   'alpukat',
#   'susu',
#   'teh hitam',
#   'telur',
#   'saus BBQ',
#   'wortel',
#   'biskuit',
#   'jus tomat',
#   'roti'],
#  ['biskuit'],
#  ['daging tanpa tulang'],
#  ['merica', 'kentang goreng', 'stroberi', 'pancake', 'susu yogurt'],
#  ['sayuran beku', 'ragi', 'ayam', 'madu', 'mayones ringan'],
#  ['cokelat', 'kecap asin'],
#  ['rempah-rempah', 'madu', 'kue', 'beras', 'snack berprotein'],
#  ['burger',
#   'cokelat',
#   'sayuran beku',
#   'daging sapi giling',
#   'air mineral',
#   'susu',
#   'mayones ringan',
#   'asparagus'],
#  ['cokelat', 'air mineral', 'corn', 'keju kemasan', 'teh hijau'],
#  ['muffin'],
#  ['daging sapi', 'minyak ikan', 'daging tanpa tulang'],
#  ['spageti', 'susu', 'tepung beras', 'mint teh hijau'],
#  ['cokelat', 'deodoran'],
#  ['sayuran beku', 'kentang goreng', 'hotdog'],
#  ['snack batangan'],
#  ['burger',
#   'udang',
#   'pasta',
#   'susu',
#   'teh hijau',
#   'kentang goreng',
#   'biskuit',
#   'minuman beralkohol'],
#  ['keju parmesan', 'daging sapi giling'],
#  ['pancake', 'tepung beras', 'snack batangan'],
#  ['telur', 'terong', 'biskuit'],
#  ['sayuran beku', 'air mineral'],
#  ['cokelat'],
#  ['bebek', 'spageti', 'susu', 'tepung beras', 'cokelat'],
#  ['pasta gandum',
#   'daging sapi giling',
#   'spageti',
#   'sup',
#   'bakso',
#   'ayam',
#   'anggur merah',
#   'minyak goreng',
#   'kecap asin',
#   'yogurt kue',
#   'snack berprotein'],
#  ['minyak goreng', 'jus tomat'],
#  ['sayuran beku', 'susu', 'telur', 'kentang goreng', 'teh hijau'],
#  ['tuna segar',
#   'spageti',
#   'minyak zaitun',
#   'minyak ikan',
#   'telur',
#   'kentang goreng',
#   'kecap asin',
#   'pancake',
#   'mayones ringan'],
#  ['saus tiram', 'madu', 'hotdog'],
#  ['susu', 'bacon', 'telur', 'kentang goreng', 'roti'],
#  ['kentang goreng', 'yogurt kue'],
#  ['susu'],
#  ['kentang goreng'],
#  ['cokelat'],
#  ['burger', 'daging sapi', 'saus tiram'],
#  ['udang',
#   'pasta',
#   'tomat',
#   'snack batangan',
#   'minyak ikan',
#   'minuman bervitamin',
#   'kentang goreng',
#   'minuman rasa',
#   'brownis'],
#  ['teh hijau'],
#  ['susu yogurt'],
#  ['bebek',
#   'spageti',
#   'air mineral',
#   'sup',
#   'bayam',
#   'soda',
#   'minuman berenergi',
#   'garam'],
#  ['bebek', 'telur'],
#  ['semprotan nyamuk', 'hotdog'],
#  ['minyak'],
#  ['sup',
#   'snack batangan',
#   'ayam',
#   'telur',
#   'kue',
#   'kentang goreng',
#   'deodoran',
#   'stroberi'],
#  ['spageti', 'cokelat', 'yogurt kue'],
#  ['bebek', 'air mineral', 'bakso'],
#  ['daging sapi giling',
#   'air mineral',
#   'cokelat',
#   'fromage blanc',
#   'bacon',
#   'hotdog'],
#  ['sayuran beku', 'air mineral', 'sayuran', 'daging tanpa tulang'],
#  ['rempah-rempah', 'saus tiram', 'tomat'],
#  ['pasta gandum', 'minyak zaitun', 'sereal', 'brownis', 'teh hijau'],
#  ['biskuit'],
#  ['minyak zaitun', 'biskuit', 'saus krim jamur'],
#  ['daging sapi giling',
#   'pancake',
#   'minyak goreng',
#   'snack rendah gula',
#   'mayones ringan'],
#  ['air mineral', 'kentang goreng'],
#  ['rempah-rempah'],
#  ['salmon'],
#  ['telur', 'daging tanpa tulang'],
#  ['air mineral', 'jus tomat'],
#  ['air mineral'],
#  ['udang', 'air mineral', 'sup', 'teh hitam'],
#  ['kue', 'minuman rasa'],
#  ['bebek',
#   'burger',
#   'keju parut',
#   'tomat',
#   'cokelat',
#   'fromage blanc',
#   'madu',
#   'tepung beras'],
#  ['sayuran beku',
#   'daging sapi giling',
#   'air mineral',
#   'minyak zaitun',
#   'pancake'],
#  ['bebek',
#   'burger',
#   'daging sapi giling',
#   'susu',
#   'minyak zaitun',
#   'kue',
#   'roti'],
#  ['pasta gandum',
#   'daging sapi giling',
#   'spageti',
#   'ragi',
#   'air mineral',
#   'sup',
#   'kacang mete',
#   'sereal',
#   'minuman berenergi',
#   'snack berprotein'],
#  ['telur', 'tepung beras', 'kue', 'teh hijau', 'daging tanpa tulang'],
#  ['daging sapi giling', 'ragi', 'sup', 'alpukat', 'salmon', 'teh hijau'],
#  ['susu'],
#  ['spageti', 'cokelat'],
#  ['pasta gandum', 'madu'],
#  ['pasta gandum', 'teh hijau'],
#  ['spageti', 'bakso', 'sayuran', 'cokelat'],
#  ['telur', 'susu yogurt'],
#  ['tuna segar',
#   'udang',
#   'pasta',
#   'air mineral',
#   'minyak zaitun',
#   'telur',
#   'kue',
#   'brownis',
#   'jus tomat'],
#  ['air mineral', 'anggur hijau', 'hotdog', 'roti'],
#  ['sayuran beku', 'bakso', 'telur', 'cokelat'],
#  ['cokelat'],
#  ['bakso', 'susu'],
#  ['susu yogurt'],
#  ['teh hijau'],
#  ['daging tanpa tulang', 'pasta'],
#  ['merica',
#   'cokelat',
#   'minyak zaitun',
#   'minyak ikan',
#   'salmon',
#   'beras',
#   'mayones ringan',
#   'roti',
#   'majalah'],
#  ['saus tiram',
#   'minyak ikan',
#   'sayuran',
#   'beras',
#   'aksesoris pakaian',
#   'hotdog',
#   'teh hijau'],
#  ['burger',
#   'minuman dessert',
#   'spageti',
#   'ayam',
#   'kue',
#   'snack berprotein',
#   'teh hijau'],
#  ['minyak ikan', 'kue', 'roti'],
#  ['burger', 'sayuran beku', 'kemiri', 'telur'],
#  ['saus tiram'],
#  ['merica', 'air mineral', 'snack batangan', 'anggur hijau'],
#  ['susu', 'telur', 'kue', 'cokelat', 'kentang goreng', 'teh hijau'],
#  ['kentang goreng'],
#  ['almond'],
#  ['burger', 'air mineral', 'teh hijau'],
#  ['susu', 'pancake'],
#  ['pancake', 'telur', 'garam', 'jus tomat'],
#  ['air mineral'],
#  ['daging sapi', 'spageti', 'air mineral', 'minyak zaitun'],
#  ['garam', 'jus tomat', 'roti'],
#  ['spageti', 'saus krim jamur'],
#  ['spageti', 'air mineral', 'telur', 'makanan binatang'],
#  ['sayuran beku', 'spageti'],
#  ['minuman berenergi'],
#  ['muffin'],
#  ['bebek', 'susu'],
#  ['biskuit'],
#  ['cokelat'],
#  ['spageti',
#   'air mineral',
#   'telur',
#   'minyak goreng',
#   'cokelat',
#   'daging tanpa tulang'],
#  ['udang', 'sayuran beku', 'merica', 'spageti', 'teh hijau'],
#  ['burger',
#   'tuna segar',
#   'saus tiram',
#   'air mineral',
#   'kentang goreng',
#   'snack berprotein',
#   'susu yogurt'],
#  ['pancake', 'telur', 'minuman berenergi', 'roti'],
#  ['keju tua',
#   'salmon',
#   'teh hijau',
#   'kentang goreng',
#   'minuman rasa',
#   'hotdog'],
#  ['keju parut', 'udang', 'pasta', 'tomat', 'susu', 'minuman rasa', 'sandwich'],
#  ['rempah-rempah', 'pasta gandum', 'minyak zaitun', 'pancake', 'telur'],
#  ['spageti', 'minuman bervitamin'],
#  ['cokelat', 'susu', 'almond', 'telur', 'stroberi', 'minuman beralkohol'],
#  ['kentang goreng', 'stroberi'],
#  ['air mineral'],
#  ['telur'],
#  ['daging tanpa tulang'],
#  ['kue'],
#  ['pasta gandum', 'minuman bervitamin', 'deodoran', 'teh hijau'],
#  ['air mineral', 'minyak', 'minuman rasa'],
#  ['kentang goreng', 'kecap asin'],
#  ['cokelat', 'kentang goreng'],
#  ['sayuran beku', 'spageti', 'telur'],
#  ['hotdog'],
#  ['cokelat', 'biskuit'],
#  ['pancake'],
#  ['udang', 'mentega', 'ayam', 'salmon'],
#  ['cokelat', 'biskuit', 'makanan bayi'],
#  ['merica', 'spageti', 'kue', 'cokelat', 'kentang goreng', 'roti'],
#  ['alpukat', 'minyak', 'sereal', 'kentang goreng'],
#  ['rempah-rempah',
#   'spageti',
#   'air mineral',
#   'bayam',
#   'telur',
#   'minyak',
#   'minyak goreng',
#   'teh hijau',
#   'sampo',
#   'jus tomat',
#   'susu yogurt'],
#  ['rempah-rempah',
#   'sayuran beku',
#   'daging sapi giling',
#   'merica',
#   'spageti',
#   'mint teh hijau',
#   'kentang goreng'],
#  ['kentang goreng'],
#  ['teh hijau', 'jus tomat'],
#  ['telur', 'tepung beras', 'cokelat'],
#  ['keju parut',
#   'rempah-rempah',
#   'saus tiram',
#   'spageti',
#   'air mineral',
#   'salmon',
#   'telur',
#   'minyak goreng',
#   'teh hijau'],
#  ['kentang goreng',
#   'biskuit',
#   'bawang merah',
#   'jus tomat',
#   'roti',
#   'susu yogurt'],
#  ['burger', 'tuna segar', 'spageti', 'muffin', 'madu'],
#  ['rempah-rempah', 'daging sapi giling', 'spageti', 'telur', 'ayam'],
#  ['keju parut', 'muffin', 'jus tomat', 'mayones'],
#  ['pasta gandum',
#   'ragi',
#   'air mineral',
#   'muffin',
#   'minuman rasa',
#   'hotdog',
#   'minuman berenergi'],
#  ['burger',
#   'spageti',
#   'sup',
#   'susu',
#   'minyak zaitun',
#   'salmon',
#   'telur',
#   'anggur merah'],
#  ['cokelat', 'kecap asin', 'majalah'],
#  ['sayuran beku',
#   'spageti',
#   'ragi',
#   'air mineral',
#   'minyak ikan',
#   'anggur hijau',
#   'beras',
#   'cokelat'],
#  ['saus tomat', 'cokelat'],
#  ['susu', 'telur'],
#  ['makanan binatang'],
#  ['yogurt kue'],
#  ['teh hijau'],
#  ['daging tanpa tulang', 'pasta'],
#  ['rempah-rempah', 'daging sapi giling'],
#  ['air mineral', 'madu', 'brownis'],
#  ['bebek', 'telur', 'kue', 'minuman berenergi'],
#  ['bebek',
#   'burger',
#   'minuman dessert',
#   'daging sapi giling',
#   'sup',
#   'salmon',
#   'telur',
#   'gom arab',
#   'jus tomat',
#   'snack batangan'],
#  ['spageti', 'air mineral', 'ayam'],
#  ['bebek', 'daging sapi giling', 'wortel', 'kentang goreng', 'semangka'],
#  ['air mineral', 'telur', 'susu yogurt'],
#  ['bebek', 'minyak goreng', 'sampo'],
#  ['spageti', 'hotdog'],
#  ['cokelat', 'teh hijau'],
#  ['keju parut',
#   'merica',
#   'air mineral',
#   'cokelat',
#   'telur',
#   'kue',
#   'kentang tumbuk',
#   'jus tomat'],
#  ['cokelat'],
#  ['spageti', 'minyak zaitun', 'keju tua', 'pancake'],
#  ['saus tiram', 'air mineral', 'sup', 'beras', 'biskuit'],
#  ['saus tiram', 'udang', 'spageti'],
#  ['teh hijau'],
#  ['air mineral', 'ayam', 'kentang goreng', 'minuman rasa'],
#  ['muffin'],
#  ['kue', 'cokelat'],
#  ['tuna segar',
#   'tomat',
#   'air mineral',
#   'sup',
#   'alpukat',
#   'bakso',
#   'minyak zaitun'],
#  ['bebek', 'kentang goreng'],
#  ['burger',
#   'bebek',
#   'rempah-rempah',
#   'daging sapi giling',
#   'pancake',
#   'telur',
#   'krim ',
#   'beras',
#   'kecap asin',
#   'roti'],
#  ['daging tanpa tulang'],
#  ['cokelat', 'daging tanpa tulang', 'roti'],
#  ['daging sapi',
#   'spageti',
#   'minyak ikan',
#   'sayuran',
#   'cokelat',
#   'kentang goreng'],
#  ['alpukat', 'mayones ringan'],
#  ['spageti', 'ragi', 'mentega', 'cokelat'],
#  ['snack batangan', 'telur', 'kentang goreng'],
#  ['tuna segar', 'saus BBQ', 'terong'],
#  ['minuman berenergi'],
#  ['tepung beras', 'kentang goreng', 'hotdog', 'teh hijau'],
#  ['air mineral', 'ayam', 'teh hijau'],
#  ['telur', 'kue', 'saus krim jamur'],
#  ['daging tanpa tulang'],
#  ['minuman bervitamin', 'daging tanpa tulang'],
#  ['udang', 'spageti', 'kentang goreng'],
#  ['keju parut', 'spageti', 'salmon', 'jus tomat'],
#  ['spageti', 'teh hijau'],
#  ['kecap asin', 'snack berprotein'],
#  ['air mineral', 'alpukat', 'cokelat'],
#  ['tomat', 'kecap asin', 'teh hijau'],
#  ['ayam', 'kentang goreng', 'daging tanpa tulang'],
#  ['sayuran beku',
#   'tomat',
#   'telur',
#   'teh hijau',
#   'minuman rasa',
#   'mayones ringan'],
#  ['daging sapi giling',
#   'ayam',
#   'cider',
#   'anggur hijau',
#   'madu',
#   'cokelat',
#   'kentang goreng',
#   'kecap asin',
#   'minuman rasa',
#   'daging tanpa tulang'],
#  ['kentang goreng', 'kecap asin'],
#  ['air mineral', 'sup'],
#  ['sayuran beku', 'spageti', 'susu', 'cokelat', 'makanan bayi'],
#  ['madu', 'tepung beras'],
#  ['tepung beras', 'ayam', 'jus tomat'],
#  ['pancake'],
#  ['teh hijau', 'snack berprotein', 'jus tomat', 'snack batangan'],
#  ['kentang goreng'],
#  ['air mineral'],
#  ['daging tanpa tulang'],
#  ['keju parut',
#   'rempah-rempah',
#   'pasta gandum',
#   'ragi',
#   'air mineral',
#   'bacon',
#   'nonfat susu',
#   'bayam'],
#  ['spageti', 'susu'],
#  ['susu', 'cokelat', 'minuman beralkohol'],
#  ['sandwich'],
#  ['cokelat', 'mayones ringan'],
#  ['udang',
#   'pasta gandum',
#   'spageti',
#   'bakso',
#   'ayam',
#   'minuman rasa',
#   'jus tomat'],
#  ['saus tiram', 'daging sapi giling', 'spageti', 'air mineral', 'telur'],
#  ['ragi', 'semangka'],
#  ['spageti', 'minyak goreng'],
#  ['kentang goreng'],
#  ['air mineral',
#   'susu',
#   'bayam',
#   'minyak goreng',
#   'cokelat',
#   'minuman rasa',
#   'hotdog'],
#  ['saus tomat', 'susu'],
#  ['udang', 'cider', 'telur', 'kentang goreng'],
#  ['kecap asin'],
#  ['salad'],
#  ['kentang goreng'],
#  ['sayuran beku',
#   'air mineral',
#   'snack batangan',
#   'madu',
#   'beras',
#   'teh hijau'],
#  ['kentang goreng', 'salad'],
#  ['madu', 'cokelat', 'kentang goreng', 'brownis'],
#  ['teh hijau', 'stroberi', 'snack rendah gula'],
#  ['sayuran beku',
#   'daging sapi giling',
#   'air mineral',
#   'salmon',
#   'madu',
#   'cokelat hitam',
#   'teh hijau',
#   'saus krim jamur',
#   'snack rendah gula'],
#  ['keju parut', 'tomat', 'air mineral', 'bakso'],
#  ['udang', 'cokelat', 'semprotan air'],
#  ['bebek'],
#  ['bebek', 'telur'],
#  ['bebek',
#   'sayuran beku',
#   'tomat',
#   'sup',
#   'mentega',
#   'minyak ikan',
#   'pancake',
#   'telur',
#   'jus tomat',
#   'roti',
#   'teh hijau'],
#  ['spageti'],
#  ['susu', 'minuman rasa', 'susu yogurt'],
#  ['burger',
#   'air mineral',
#   'susu',
#   'tepung beras',
#   'sereal',
#   'cokelat',
#   'kentang goreng'],
#  ['air mineral'],
#  ['tomat', 'air mineral', 'sup', 'kue', 'cokelat'],
#  ['air mineral'],
#  ['daging sapi giling', 'spageti'],
#  ['merica', 'minuman rasa'],
#  ['yogurt kue'],
#  ['saus tiram', 'pancake'],
#  ['snack batangan'],
#  ['telur', 'kentang goreng', 'susu yogurt'],
#  ['biskuit'],
#  ['biskuit'],
#  ['spageti',
#   'sup',
#   'sayuran',
#   'bayam',
#   'kentang goreng',
#   'daging tanpa tulang',
#   'brokoli',
#   'pasta gigi'],
#  ['biskuit'],
#  ['sup', 'minyak zaitun', 'telur', 'soda', 'corn'],
#  ['cokelat', 'minuman rasa', 'susu yogurt'],
#  ['spageti', 'air mineral', 'susu', 'pancake', 'cokelat', 'kentang goreng'],
#  ['air mineral'],
#  ['rempah-rempah',
#   'sayuran beku',
#   'saus tomat',
#   'air mineral',
#   'sup',
#   'susu',
#   'minyak zaitun',
#   'almond'],
#  ['burger', 'telur'],
#  ['kentang goreng'],
#  ['minuman rasa', 'keju kemasan'],
#  ['tomat', 'air mineral', 'cokelat', 'mayones ringan'],
#  ['salmon',
#   'daging tanpa tulang',
#   'bawang merah',
#   'stroberi',
#   'roti',
#   'susu yogurt'],
#  ['snack batangan'],
#  ['saus tiram',
#   'daging sapi giling',
#   'spageti',
#   'pancake',
#   'anggur merah',
#   'minyak',
#   'minyak goreng',
#   'jus tomat'],
#  ['daging sapi giling',
#   'spageti',
#   'air mineral',
#   'susu',
#   'minuman rasa',
#   'kecap asin'],
#  ['biskuit'],
#  ['salmon', 'daging tanpa tulang'],
#  ['biskuit'],
#  ['susu yogurt'],
#  ['telur'],
#  ['saus tiram', 'mentega', 'hotdog'],
#  ['tomat', 'air mineral', 'sup', 'kentang tumbuk'],
#  ['biskuit'],
#  ['keju parmesan', 'daging sapi giling', 'salmon', 'pancake', 'kecap asin'],
#  ['daging sapi giling', 'ragi', 'cokelat', 'minyak zaitun', 'telur'],
#  ['udang', 'salmon', 'telur', 'biskuit', 'hotdog'],
#  ['majalah', 'mint'],
#  ['bebek',
#   'air mineral',
#   'telur',
#   'minyak goreng',
#   'cokelat hitam',
#   'daging tanpa tulang'],
#  ['air mineral', 'saus krim jamur'],
#  ['keju parut', 'sayuran beku', 'air mineral', 'sup', 'susu', 'minyak ikan'],
#  ['cokelat', 'kue'],
#  ['burger', 'garam', 'minuman beralkohol'],
#  ['minuman berenergi'],
#  ['minyak zaitun', 'kue', 'minuman berenergi'],
#  ['daging sapi giling', 'tepung beras'],
#  ['telur', 'kentang goreng'],
#  ['spageti', 'daging tanpa tulang', 'saus krim jamur'],
#  ['air mineral', 'fromage blanc', 'tepung beras', 'kue', 'kentang goreng'],
#  ['bebek',
#   'burger',
#   'sayuran beku',
#   'daging sapi giling',
#   'air mineral',
#   'susu',
#   'telur',
#   'kue',
#   'mayones ringan'],
#  ['teh hijau', 'keju kemasan'],
#  ['tuna segar', 'telur', 'kecap asin'],
#  ['biskuit'],
#  ['biskuit'],
#  ['biskuit'],
#  ['tomat', 'air mineral', 'terong'],
#  ['keju parut',
#   'tomat',
#   'spageti',
#   'air mineral',
#   'sup',
#   'madu',
#   'ayam',
#   'cokelat',
#   'kentang goreng'],
#  ['snack berprotein'],
#  ['rempah-rempah',
#   'saus tiram',
#   'udang',
#   'air mineral',
#   'saus BBQ',
#   'snack berprotein'],
#  ['burger',
#   'daging sapi',
#   'spageti',
#   'air mineral',
#   'susu',
#   'telur',
#   'kentang goreng',
#   'daging tanpa tulang',
#   'pancake',
#   'susu yogurt'],
#  ['kentang goreng'],
#  ['sayuran beku',
#   'sup',
#   'susu',
#   'telur',
#   'tepung beras',
#   'cokelat',
#   'daging tanpa tulang',
#   'semangka'],
#  ['spageti'],
#  ['rempah-rempah',
#   'udang',
#   'sup',
#   'telur',
#   'minyak',
#   'minyak goreng',
#   'minuman berenergi',
#   'snack berprotein',
#   'susu yogurt'],
#  ['daging sapi',
#   'keju parut',
#   'rempah-rempah',
#   'udang',
#   'daging sapi giling',
#   'spageti',
#   'air mineral',
#   'wortel'],
#  ['daging sapi',
#   'saus tiram',
#   'daging sapi giling',
#   'ragi',
#   'air mineral',
#   'cokelat',
#   'susu yogurt'],
#  ['cokelat',
#   'kentang goreng',
#   'saus krim jamur',
#   'keju kemasan',
#   'susu yogurt'],
#  ['telur'],
#  ['kue', 'biskuit'],
#  ['keju parut', 'air mineral', 'kue', 'cokelat bread'],
#  ['tomat', 'almond', 'kue', 'kecap asin', 'susu yogurt'],
#  ['rempah-rempah',
#   'udang',
#   'sayuran beku',
#   'susu',
#   'mentega',
#   'salmon',
#   'telur',
#   'cokelat'],
#  ['rempah-rempah',
#   'udang',
#   'pasta gandum',
#   'tepung beras',
#   'ayam',
#   'teh hijau',
#   'brokoli'],
#  ['telur', 'corn'],
#  ['udang',
#   'sayuran beku',
#   'saus tomat',
#   'air mineral',
#   'cokelat',
#   'sup',
#   'minyak zaitun',
#   'salmon',
#   'kacang polong',
#   'kecap asin'],
#  ['daging sapi',
#   'rempah-rempah',
#   'saus tomat',
#   'air mineral',
#   'anggur hijau',
#   'telur',
#   'gom arab',
#   'krim ',
#   'minyak',
#   'teh hijau',
#   'mint'],
#  ['snack batangan', 'kue', 'cokelat'],
#  ['rempah-rempah', 'udang', 'spageti', 'telur'],
#  ['tuna segar', 'air mineral', 'madu', 'minyak goreng'],
#  ['saus tiram',
#   'air mineral',
#   'minyak',
#   'kecap manis',
#   'cabe',
#   'makanan binatang',
#   'terong',
#   'teh hijau',
#   'daging tanpa tulang',
#   'jus tomat',
#   'susu yogurt'],
#  ['rempah-rempah',
#   'udang',
#   'air mineral',
#   'pancake',
#   'telur',
#   'kue',
#   'anggur merah',
#   'tea',
#   'minuman rasa'],
#  ['daging sapi giling', 'air mineral', 'snack berprotein'],
#  ['udang',
#   'sayuran beku',
#   'keju parmesan',
#   'spageti',
#   'salmon',
#   'wortel',
#   'minuman rasa',
#   'pasta',
#   'kentang tumbuk',
#   'bawang merah',
#   'mayones ringan',
#   'majalah'],
#  ['susu', 'cokelat'],
#  ['sayuran beku',
#   'daging sapi giling',
#   'spageti',
#   'minyak zaitun',
#   'tepung beras',
#   'terong',
#   'keju kemasan'],
#  ['bebek', 'daging sapi giling', 'susu yogurt'],
#  ['rempah-rempah',
#   'spageti',
#   'air mineral',
#   'tepung beras',
#   'kue',
#   'hotdog',
#   'teh hijau'],
#  ['teh hijau'],
#  ['biskuit'],
#  ['telur', 'biskuit'],
#  ['spageti',
#   'telur',
#   'daging sapi',
#   'cokelat',
#   'kentang goreng',
#   'kecap asin',
#   'brownis',
#   'pancake',
#   'mayones ringan'],
#  ['saus tiram', 'spageti', 'susu', 'telur', 'cokelat'],
#  ['bebek', 'burger', 'pancake', 'kentang goreng', 'stroberi', 'teh hijau'],
#  ['daging tanpa tulang'],
#  ['sayuran beku', 'pancake', 'telur', 'kue'],
#  ['kentang goreng'],
#  ['bebek', 'daging sapi giling', 'merica', 'spageti', 'madu', 'biskuit'],
#  ['cokelat',
#   'saus tiram',
#   'saus tomat',
#   'minyak zaitun',
#   'cabe',
#   'kentang goreng',
#   'biskuit',
#   'garam',
#   'roti',
#   'majalah'],
#  ['teh hijau', 'kentang goreng'],
#  ['air mineral'],
#  ['minyak goreng'],
#  ['sayuran beku', 'spageti'],
#  ['daging sapi', 'spageti'],
#  ['ayam', 'cokelat', 'biskuit'],
#  ['susu yogurt'],
#  ['telur', 'kue', 'susu yogurt'],
#  ['udang',
#   'spageti',
#   'air mineral',
#   'sup',
#   'susu',
#   'bramble',
#   'minuman rasa',
#   'keju kemasan'],
#  ['air mineral', 'telur', 'snack berprotein'],
#  ['bebek', 'udang', 'bakso', 'mentega', 'telur', 'salad', 'teh hijau'],
#  ['tuna segar',
#   'spageti',
#   'cokelat',
#   'minyak zaitun',
#   'ayam',
#   'kentang goreng'],
#  ['bebek', 'udang', 'daging tanpa tulang', 'hotdog'],
#  ['burger', 'merica', 'sup', 'susu', 'pancake', 'teh hijau'],
#  ['pancake'],
#  ['air mineral', 'pancake', 'telur', 'kentang goreng'],
#  ['telur', 'daging tanpa tulang', 'susu yogurt'],
#  ['air mineral', 'minyak ikan', 'snack rendah gula'],
#  ['burger', 'daging sapi giling', 'spageti', 'telur', 'kentang goreng'],
#  ['sup', 'bakso', 'susu', 'snack batangan'],
#  ['cokelat'],
#  ['rempah-rempah'],
#  ['bebek', 'saus tiram', 'air mineral', 'telur', 'bramble'],
#  ['burger',
#   'daging sapi',
#   'sayuran beku',
#   'tomat',
#   'kue',
#   'ayam',
#   'teh hijau',
#   'pasta gigi',
#   'mint'],
#  ['keju parut', 'air mineral', 'minyak zaitun', 'snack batangan'],
#  ['susu', 'kue', 'teh hijau'],
#  ['air mineral',
#   'almond',
#   'minyak goreng',
#   'sereal',
#   'snack berprotein',
#   'minuman beralkohol',
#   'teh hijau'],
#  ['bebek',
#   'tuna segar',
#   'air mineral',
#   'susu',
#   'telur',
#   'kue',
#   'burger sauce',
#   'ayam',
#   'kentang goreng',
#   'minuman rasa',
#   'roti'],
#  ['rempah-rempah', 'air mineral', 'tepung beras', 'yogurt kue', 'susu yogurt'],
#  ['tomat', 'spageti', 'bakso', 'ayam', 'telur'],
#  ['burger', 'air mineral', 'telur', 'teh hijau', 'pancake'],
#  ['kue', 'teh hijau'],
#  ['cokelat', 'rempah-rempah', 'yogurt kue'],
#  ['daging sapi giling',
#   'spageti',
#   'air mineral',
#   'almond',
#   'salmon',
#   'nonfat susu',
#   'anggur hijau',
#   'pancake'],
#  ['air mineral', 'sayuran', 'telur'],
#  ['snack berprotein'],
#  ['telur', 'terong'],
#  ['mayones'],
#  ['susu', 'semprotan nyamuk', 'oatmeal', 'sandwich', 'asparagus'],
#  ['sayuran beku', 'sup', 'almond', 'telur', 'kentang goreng'],
#  ['sayuran beku'],
#  ['sup', 'mentega', 'sampo'],
#  ['rempah-rempah', 'pasta gandum', 'merica', 'telur'],
#  ['air mineral',
#   'tepung beras',
#   'beras',
#   'minyak goreng',
#   'cokelat',
#   'roti',
#   'susu yogurt'],
#  ['keju parut', 'mentega', 'cokelat', 'kentang goreng', 'biskuit'],
#  ['spageti',
#   'sup',
#   'susu',
#   'kacang mete',
#   'minyak goreng',
#   'asparagus',
#   'jus tomat'],
#  ['telur',
#   'kentang goreng',
#   'minuman rasa',
#   'biskuit',
#   'kecap asin',
#   'keju kemasan',
#   'teh hijau'],
#  ['bebek', 'tomat', 'air mineral', 'telur', 'anggur merah'],
#  ['susu', 'jus tomat', 'susu yogurt', 'teh hijau'],
#  ['air mineral', 'sup', 'almond', 'sereal', 'teh hijau'],
#  ['cokelat', 'mayones ringan'],
#  ['bebek', 'rempah-rempah', 'cokelat'],
#  ['telur', 'kentang goreng', 'teh hijau'],
#  ['air mineral', 'kue', 'cokelat', 'jus tomat'],
#  ['telur'],
#  ['cokelat',
#   'merica',
#   'spageti',
#   'air mineral',
#   'tepung beras',
#   'kecap asin',
#   'saus krim jamur'],
#  ['sayuran beku', 'merica', 'air mineral', 'cokelat', 'minuman beralkohol'],
#  ['burger',
#   'bebek',
#   'spageti',
#   'susu',
#   'tepung beras',
#   'minyak',
#   'jus tomat',
#   'teh hijau'],
#  ['burger',
#   'spageti',
#   'air mineral',
#   'sup',
#   'minyak ikan',
#   'kentang goreng',
#   'mayones ringan',
#   'susu yogurt'],
#  ['mentega', 'anggur hijau', 'minuman rasa', 'susu yogurt'],
#  ['telur', 'susu yogurt'],
#  ['biskuit'],
#  ['susu', 'minuman berenergi'],
#  ['minyak zaitun', 'minuman berenergi'],
#  ['telur', 'biskuit'],
#  ['telur'],
#  ['snack batangan', 'telur'],
#  ['telur'],
#  ['telur', 'teh hijau'],
#  ['daging tanpa tulang'],
#  ['udang', 'sup', 'susu', 'almond', 'telur', 'minyak', 'cokelat'],
#  ['cokelat', 'kentang goreng'],
#  ['kue'],
#  ['pancake', 'telur', 'kue', 'teh hijau', 'pasta gigi'],
#  ['rempah-rempah', 'tomat', 'daging sapi giling', 'telur', 'minyak goreng'],
#  ['cider', 'telur', 'cokelat', 'susu yogurt'],
#  ['sayuran beku', 'cider', 'telur', 'kentang goreng'],
#  ['ragi', 'biskuit', 'pasta gigi'],
#  ['air mineral',
#   'susu',
#   'daging tanpa tulang',
#   'kecap asin',
#   'hotdog',
#   'roti'],
#  ['daging sapi',
#   'rempah-rempah',
#   'spageti',
#   'air mineral',
#   'cokelat',
#   'pancake',
#   'telur'],
#  ['merica',
#   'air mineral',
#   'daging tanpa tulang',
#   'bawang merah',
#   'snack berprotein',
#   'minuman beralkohol'],
#  ['bebek', 'keju parmesan', 'spageti', 'bakso', 'mentega'],
#  ['rempah-rempah', 'telur', 'daging tanpa tulang'],
#  ['rempah-rempah'],
#  ['burger', 'daging tanpa tulang', 'bawang merah'],
#  ['cokelat', 'merica', 'saus tomat', 'jus tomat'],
#  ['biskuit'],
#  ['burger',
#   'daging sapi giling',
#   'spageti',
#   'air mineral',
#   'daging tanpa tulang',
#   'semangka'],
#  ['sayuran beku', 'air mineral', 'sup', 'susu', 'minyak zaitun'],
#  ['bebek', 'telur', 'kentang goreng', 'asparagus', 'susu yogurt', 'laos'],
#  ['burger', 'sayuran beku', 'gom arab'],
#  ['rempah-rempah', 'sayuran beku', 'daging sapi giling', 'susu'],
#  ['sayuran beku', 'kue', 'krim ', 'kentang tumbuk'],
#  ['susu'],
#  ['bebek', 'telur', 'saus BBQ'],
#  ['daging tanpa tulang'],
#  ['keju parmesan', 'kentang goreng'],
#  ['snack batangan', 'telur'],
#  ['sup', 'daging tanpa tulang', 'mint'],
#  ['muffin', 'ayam', 'laos'],
#  ['burger', 'telur', 'kentang goreng', 'biskuit', 'teh hijau'],
#  ['spageti'],
#  ['alpukat', 'snack batangan', 'cokelat'],
#  ['biskuit'],
#  ['teh hijau'],
#  ['pasta gandum', 'spageti', 'air mineral', 'minyak zaitun'],
#  ['keju parut',
#   'sayuran beku',
#   'telur',
#   'gom arab',
#   'daging tanpa tulang',
#   'susu yogurt'],
#  ['keju parut',
#   'rempah-rempah',
#   'air mineral',
#   'pancake',
#   'cokelat',
#   'daging tanpa tulang',
#   'jus tomat'],
#  ['cokelat', 'spageti', 'ragi', 'kemiri', 'salmon', 'minuman rasa'],
#  ['burger sauce', 'minyak'],
#  ['telur', 'kentang goreng', 'minuman berenergi'],
#  ['air mineral'],
#  ['keju parut', 'daging sapi giling', 'air mineral', 'minyak zaitun'],
#  ['telur', 'susu yogurt'],
#  ['keju parmesan',
#   'spageti',
#   'soda',
#   'makanan binatang',
#   'minuman beralkohol'],
#  ['bebek',
#   'udang',
#   'minyak zaitun',
#   'ayam',
#   'telur',
#   'cokelat hitam',
#   'semangka',
#   'roti'],
#  ['acar',
#   'daging sapi giling',
#   'ragi',
#   'susu',
#   'keju tua',
#   'salmon',
#   'muffin',
#   'kentang goreng',
#   'daging tanpa tulang'],
#  ['merica', 'spageti', 'krim '],
#  ['sayuran beku', 'air mineral', 'telur'],
#  ['spageti', 'ayam', 'tea', 'pancake', 'snack rendah gula'],
#  ['tuna segar', 'bebek', 'rempah-rempah', 'spageti', 'air mineral', 'mint'],
#  ['spageti', 'air mineral', 'minyak goreng', 'daging tanpa tulang'],
#  ['sup'],
#  ['burger', 'rempah-rempah', 'spageti'],
#  ['biskuit', 'bawang merah', 'stroberi'],
#  ['tuna segar',
#   'cokelat',
#   'udang',
#   'pasta gandum',
#   'merica',
#   'air mineral',
#   'sup',
#   'susu',
#   'salmon'],
#  ['ragi',
#   'air mineral',
#   'alpukat',
#   'susu',
#   'mentega',
#   'minyak goreng',
#   'cokelat',
#   'keju kemasan'],
#  ['daging sapi', 'telur', 'kentang goreng', 'minuman berenergi'],
#  ['air mineral', 'alpukat'],
#  ['biskuit'],
#  ['cokelat', 'mentega', 'telur', 'teh hijau', 'keju kemasan', 'mayones'],
#  ['telur', 'saus krim jamur', 'susu yogurt'],
#  ['minuman bervitamin', 'cokelat'],
#  ['daging sapi giling', 'spageti', 'kentang goreng', 'teh hijau'],
#  ['kue'],
#  ['bebek',
#   'saus tiram',
#   'air mineral',
#   'pancake',
#   'telur',
#   'tepung beras',
#   'minyak goreng',
#   'cokelat',
#   'laos'],
#  ['cokelat', 'keju parmesan', 'air mineral', 'minyak zaitun', 'bacon'],
#  ['anggur hijau', 'gom arab'],
#  ['udang',
#   'sayuran beku',
#   'keju parmesan',
#   'susu',
#   'telur',
#   'minyak goreng',
#   'cokelat',
#   'kentang goreng'],
#  ['daging sapi giling', 'air mineral', 'susu', 'telur'],
#  ['daging tanpa tulang'],
#  ['bebek', 'biskuit'],
#  ['daging sapi giling', 'air mineral', 'cokelat', 'teh hijau'],
#  ['pasta gandum',
#   'spageti',
#   'minyak zaitun',
#   'mentega',
#   'cokelat',
#   'kentang goreng',
#   'jus tomat',
#   'susu yogurt'],
#  ['saus tiram'],
#  ['sayuran beku',
#   'air mineral',
#   'telur',
#   'gom arab',
#   'minyak goreng',
#   'minuman rasa',
#   'keju kemasan',
#   'susu yogurt'],
#  ['bebek', 'keju parut', 'snack batangan', 'sayuran', 'brownis'],
#  ['bebek', 'burger', 'nonfat susu', 'minyak goreng', 'minuman berenergi'],
#  ['kentang goreng', 'susu yogurt'],
#  ['muffin'],
#  ['rempah-rempah',
#   'air mineral',
#   'salmon',
#   'tepung beras',
#   'kue',
#   'teh hijau'],
#  ['air mineral', 'kue', 'cokelat', 'susu yogurt', 'snack batangan'],
#  ['keju parut',
#   'air mineral',
#   'cokelat',
#   'sup',
#   'susu',
#   'minyak zaitun',
#   'krim ',
#   'ayam'],
#  ['air mineral', 'stroberi'],
#  ['daging tanpa tulang'],
#  ['keju parut', 'keju parmesan', 'mentega', 'tepung beras', 'minyak goreng'],
#  ['daging sapi giling', 'mint'],
#  ['biskuit'],
#  ['daging sapi giling', 'alpukat', 'susu', 'ayam', 'beras'],
#  ['sayuran beku', 'sup', 'telur', 'susu yogurt'],
#  ['rempah-rempah',
#   'daging sapi giling',
#   'spageti',
#   'air mineral',
#   'cokelat',
#   'teh hitam',
#   'minyak ikan',
#   'pancake',
#   'beras',
#   'teh hijau',
#   'pasta gigi'],
#  ['udang',
#   'keju parmesan',
#   'air mineral',
#   'telur',
#   'kue',
#   'minyak',
#   'minyak goreng',
#   'pasta gigi',
#   'susu yogurt'],
#  ['daging sapi',
#   'rempah-rempah',
#   'sayuran beku',
#   'tomat',
#   'spageti',
#   'minyak zaitun',
#   'teh hitam',
#   'sayuran',
#   'minyak goreng',
#   'teh hijau',
#   'minuman rasa',
#   'mint'],
#  ['ayam', 'cider', 'telur'],
#  ['udang',
#   'saus tomat',
#   'air mineral',
#   'cokelat',
#   'daging tanpa tulang',
#   'mint'],
#  ['minuman berenergi'],
#  ['daging sapi',
#   'spageti',
#   'air mineral',
#   'snack batangan',
#   'telur',
#   'minyak goreng',
#   'pancake',
#   'roti',
#   'susu yogurt'],
#  ['udang', 'sayuran beku', 'tomat'],
#  ['bebek',
#   'rempah-rempah',
#   'sayuran beku',
#   'daging sapi giling',
#   'ragi',
#   'air mineral',
#   'salmon'],
#  ['udang', 'air mineral'],
#  ['bebek',
#   'daging sapi giling',
#   'spageti',
#   'sup',
#   'daging tanpa tulang',
#   'yogurt kue'],
#  ['udang',
#   'merica',
#   'air mineral',
#   'sup',
#   'susu',
#   'telur',
#   'beras',
#   'saus BBQ',
#   'aksesoris pakaian',
#   'biskuit'],
#  ['burger', 'pancake'],
#  ['susu yogurt'],
#  ['air mineral', 'susu'],
#  ['susu'],
#  ['cokelat'],
#  ['pasta gandum', 'air mineral', 'minyak zaitun', 'pancake'],
#  ['ragi', 'air mineral', 'telur', 'kue'],
#  ['bebek', 'kentang goreng'],
#  ['udang',
#   'spageti',
#   'ragi',
#   'air mineral',
#   'cokelat',
#   'minyak zaitun',
#   'krim ',
#   'ayam',
#   'teh hijau',
#   'kentang goreng',
#   'sandwich',
#   'minuman beralkohol'],
#  ['air mineral', 'susu', 'salmon', 'teh hijau', 'biskuit', 'roti'],
#  ['spageti', 'minyak zaitun'],
#  ['rempah-rempah', 'spageti'],
#  ['spageti',
#   'air mineral',
#   'sup',
#   'salmon',
#   'pancake',
#   'ayam',
#   'mint teh hijau',
#   'susu yogurt'],
#  ['sayuran beku',
#   'pasta gandum',
#   'daging sapi giling',
#   'air mineral',
#   'cokelat',
#   'susu',
#   'minyak zaitun',
#   'almond',
#   'minyak ikan',
#   'yogurt kue',
#   'roti'],
#  ['teh hijau'],
#  ['burger',
#   'keju parut',
#   'spageti',
#   'nonfat susu',
#   'telur',
#   'gom arab',
#   'cokelat',
#   'jus tomat',
#   'susu yogurt'],
#  ['daging sapi',
#   'daging sapi giling',
#   'minyak zaitun',
#   'snack batangan',
#   'ayam',
#   'brownis',
#   'minuman beralkohol'],
#  ['pasta gandum',
#   'air mineral',
#   'minyak zaitun',
#   'minyak goreng',
#   'minuman rasa',
#   'teh hijau'],
#  ['sayuran', 'kecap asin'],
#  ['minyak zaitun'],
#  ['rempah-rempah',
#   'daging sapi giling',
#   'daging tanpa tulang',
#   'pancake',
#   'teh hijau'],
#  ['rempah-rempah',
#   'sayuran beku',
#   'daging sapi giling',
#   'saus tomat',
#   'spageti',
#   'air mineral',
#   'susu',
#   'minyak ikan',
#   'telur',
#   'tepung beras',
#   'cokelat',
#   'daging tanpa tulang',
#   'hotdog',
#   'teh hijau'],
#  ['ragi', 'wortel'],
#  ['ayam'],
#  ['bebek',
#   'burger',
#   'rempah-rempah',
#   'daging sapi giling',
#   'ragi',
#   'air mineral',
#   'alpukat',
#   'susu',
#   'almond',
#   'muffin',
#   'telur',
#   'kentang goreng'],
#  ['pasta gandum', 'salmon', 'minuman bervitamin', 'mint teh hijau'],
#  ['cokelat', 'kentang goreng', 'stroberi', 'roti'],
#  ['burger',
#   'cokelat',
#   'udang',
#   'pasta gandum',
#   'daging sapi giling',
#   'sup',
#   'snack batangan',
#   ' asparagus'],
#  ['air mineral',
#   'mentega',
#   'pancake',
#   'kentang goreng',
#   'minuman rasa',
#   'minuman beralkohol',
#   'susu yogurt'],
#  ['muffin', 'telur'],
#  ['bebek', 'udang', 'sayuran beku', 'telur'],
#  ['burger', 'telur', 'yogurt kue'],
#  ['burger',
#   'tuna segar',
#   'udang',
#   'sayuran beku',
#   'pasta gandum',
#   'ragi',
#   'air mineral',
#   'minyak zaitun',
#   'almond',
#   'kue',
#   'ayam',
#   'cokelat hitam'],
#  ['rempah-rempah', 'daging sapi giling', 'air mineral', 'ayam'],
#  ['minuman rasa'],
#  ['ayam', 'jus tomat'],
#  ['pasta gandum', 'minyak zaitun'],
#  ['susu', 'snack batangan', 'teh hijau'],
#  ['keju parut', 'rempah-rempah'],
#  ['daging tanpa tulang', 'teh hijau'],
#  ['sup', 'bakso', 'susu', 'almond', 'teh hijau'],
#  ['rempah-rempah', 'makanan binatang', 'biskuit'],
#  ['keju parut',
#   'pasta gandum',
#   'minyak zaitun',
#   'snack batangan',
#   'krim ',
#   'minyak',
#   'kentang goreng',
#   'pancake',
#   'susu yogurt'],
#  ['madu'],
#  ['keju parmesan',
#   'air mineral',
#   'fromage blanc',
#   'telur',
#   'madu',
#   'minuman rasa'],
#  ['bramble', 'laos'],
#  ['daging sapi giling',
#   'merica',
#   'susu',
#   'telur',
#   'teh hijau',
#   'cokelat',
#   'minuman beralkohol'],
#  ['cokelat',
#   'saus tiram',
#   'mentega',
#   'kentang goreng',
#   'biskuit',
#   'susu yogurt'],
#  ['cokelat', 'spageti', 'semprotan nyamuk'],
#  ['biskuit'],
#  ['spageti', 'air mineral', 'sayuran', 'telur', 'tepung beras', 'roti'],
#  ['cokelat',
#   'keju parut',
#   'air mineral',
#   'salmon',
#   'tepung beras',
#   'burger sauce',
#   'daging tanpa tulang',
#   'saus krim jamur',
#   'susu yogurt'],
#  ['spageti', 'kecap asin'],
#  ['sayuran beku', 'air mineral'],
#  ['air mineral', 'deodoran', 'susu yogurt'],
#  ['rempah-rempah', 'saus tiram', 'pasta gandum', 'kue', 'jus tomat'],
#  ['burger', 'keju parmesan', 'telur', 'kentang goreng', 'hotdog'],
#  ['air mineral', 'telur', 'pancake'],
#  ['telur', 'kentang goreng'],
#  ['udang', 'sayuran beku', 'tomat', 'spageti'],
#  ['air mineral',
#   'almond',
#   'pancake',
#   'cokelat',
#   'kentang goreng',
#   'teh hijau'],
#  ['kue', 'kentang goreng', 'daging tanpa tulang'],
#  ['sayuran beku',
#   'spageti',
#   'air mineral',
#   'susu',
#   'teh hitam',
#   'minyak ikan',
#   'cider',
#   'kacang mete',
#   'salmon'],
#  ['almond', 'kue', 'susu yogurt'],
#  ['kentang goreng'],
#  ['hotdog'],
#  ['air mineral',
#   'sup',
#   'ayam',
#   'krim ',
#   'teh hijau',
#   'cokelat',
#   'kecap asin',
#   'susu yogurt'],
#  ['daging sapi giling', 'minyak zaitun'],
#  ['kentang goreng', 'biskuit', 'teh hijau'],
#  ['sup',
#   'anggur merah',
#   'minyak goreng',
#   'cokelat',
#   'biskuit',
#   'kecap asin',
#   'garam'],
#  ['cokelat', 'kentang goreng', 'minuman rasa', 'daging tanpa tulang', 'roti'],
#  ['ragi', 'mint'],
#  ['sayuran beku',
#   'daging sapi giling',
#   'salmon',
#   'muffin',
#   'cokelat',
#   'majalah'],
#  ['tuna segar',
#   'rempah-rempah',
#   'keju parmesan',
#   'susu',
#   'minyak zaitun',
#   'pancake',
#   'madu',
#   'kue',
#   'cokelat'],
#  ['keju parut',
#   'udang',
#   'mentega',
#   'tepung beras',
#   'kentang goreng',
#   'daging tanpa tulang',
#   'biskuit',
#   'keju kemasan'],
#  ['snack batangan', 'telur', 'kentang goreng', 'kecap asin', 'deodoran'],
#  ['burger', 'telur', 'kentang goreng'],
#  ['burger',
#   'udang',
#   'air mineral',
#   'susu',
#   'telur',
#   'cokelat',
#   'kentang goreng',
#   'roti'],
#  ['daging sapi giling',
#   'air mineral',
#   'cokelat',
#   'susu',
#   'ayam',
#   'nonfat susu',
#   'teh hijau'],
#  ['air mineral', 'ayam'],
#  ['bebek', 'daging sapi giling', 'spageti', 'susu', 'telur', 'kue'],
#  ['kentang goreng', 'teh hijau'],
#  ['kentang goreng', 'daging tanpa tulang'],
#  ['bebek', 'minuman soda'],
#  ['pasta gandum',
#   'air mineral',
#   'minyak zaitun',
#   'wortel',
#   'snack berprotein',
#   'susu yogurt'],
#  ['biskuit'],
#  ['bebek', 'keju parut', 'madu', 'kacang polong', 'kentang goreng'],
#  ['bebek',
#   'saus tiram',
#   'air mineral',
#   'cokelat',
#   'sup',
#   'krim ',
#   'beras',
#   'minyak',
#   'ayam',
#   'saus BBQ'],
#  ['bebek', 'telur'],
#  ['susu yogurt'],
#  ['nonfat susu', 'susu yogurt'],
#  ['sayuran beku', 'susu yogurt'],
#  ['rempah-rempah',
#   'keju parmesan',
#   'pasta gandum',
#   'air mineral',
#   'susu',
#   'telur',
#   'susu yogurt',
#   'mint'],
#  ['yogurt kue', 'mint'],
#  ['sandwich', 'garam'],
#  ['udang', 'roti', 'teh hijau'],
#  ['merica', 'saus tomat', 'daging tanpa tulang'],
#  ['air mineral', 'kue', 'snack berprotein', 'pasta gigi'],
#  ['snack batangan'],
#  ['saus tiram'],
#  ['spageti', 'air mineral', 'madu', 'stroberi'],
#  ['air mineral', 'telur', 'teh hijau'],
#  ['keju parut',
#   'sayuran beku',
#   'keju parmesan',
#   'minyak ikan',
#   'kentang goreng',
#   'roti',
#   'teh hijau'],
#  ['sayuran beku',
#   'keju parmesan',
#   'pasta gandum',
#   'spageti',
#   'air mineral',
#   'cokelat',
#   'alpukat',
#   'susu',
#   'minyak zaitun',
#   'muffin',
#   'kue'],
#  ['cokelat',
#   'keju parut',
#   'udang',
#   'spageti',
#   'minyak zaitun',
#   'madu',
#   'stroberi',
#   'mint'],
#  ['spageti', 'stroberi'],
#  ['burger', 'cokelat', 'saus krim jamur'],
#  ['air mineral', 'minyak zaitun', 'cokelat hitam'],
#  ['telur', 'teh hijau'],
#  ['jus tomat'],
#  ['muffin', 'susu yogurt'],
#  ['sup', 'minyak zaitun', 'pancake', 'krim ', 'kecap asin', 'susu yogurt'],
#  ['air mineral', 'sayuran', 'susu yogurt'],
#  ['merica',
#   'air mineral',
#   'alpukat',
#   'pancake',
#   'telur',
#   'madu',
#   'teh hijau',
#   'cokelat'],
#  ['acar', 'burger', 'almond', 'madu', 'minuman rasa'],
#  ['semprotan nyamuk', 'aksesoris pakaian', 'keju kemasan'],
#  ['sayuran beku',
#   'daging sapi giling',
#   'spageti',
#   'pancake',
#   'madu',
#   'tepung beras',
#   'kacang polong',
#   'kentang goreng',
#   'minuman rasa',
#   'kentang tumbuk'],
#  ['spageti', 'air mineral', 'susu'],
#  ['pancake'],
#  ['muffin'],
#  ['sayuran beku', 'minyak', 'sereal'],
#  ['bebek',
#   'udang',
#   'air mineral',
#   'susu',
#   'almond',
#   'keju tua',
#   'kue',
#   'minuman rasa'],
#  ['cokelat', 'beras', 'terong', 'snack berprotein', 'laos'],
#  ['spageti', 'bakso', 'nonfat susu', 'hotdog'],
#  ['sayuran beku', 'kue', 'biskuit', 'pancake'],
#  ['mentega', 'semprotan nyamuk', 'kentang goreng', 'yogurt kue', 'teh hijau'],
#  ['rempah-rempah'],
#  ['sup', 'susu', 'cider', 'ayam', 'kacang polong'],
#  ['udang',
#   'spageti',
#   'air mineral',
#   'alpukat',
#   'susu',
#   'salmon',
#   'minuman rasa',
#   'daging tanpa tulang',
#   'hotdog'],
#  ['susu', 'tepung beras', 'daging tanpa tulang', 'kecap asin'],
#  ['daging tanpa tulang', 'pasta', 'saus krim jamur'],
#  ['keju parmesan'],
#  ['keju parut', 'spageti', 'kentang goreng'],
#  ['burger',
#   'udang',
#   'pasta gandum',
#   'spageti',
#   'air mineral',
#   'susu',
#   'minyak zaitun',
#   'ayam',
#   'salmon',
#   'pancake',
#   'kue'],
#  ['bebek',
#   'cokelat',
#   'keju parut',
#   'sayuran beku',
#   'daging sapi giling',
#   'spageti',
#   'susu',
#   'mentega',
#   'bacon',
#   'tepung beras'],
#  ['bebek',
#   'merica',
#   'cokelat',
#   'fromage blanc',
#   'telur',
#   'teh hijau',
#   'daging tanpa tulang'],
#  ['tomat', 'daging sapi giling', 'alpukat', 'susu', 'pancake', 'teh hijau'],
#  ['bebek', 'air mineral', 'teh hijau', 'snack berprotein'],
#  ['air mineral', 'susu yogurt'],
#  ['pancake', 'jus tomat', 'snack batangan'],
#  ['ragi',
#   'alpukat',
#   'bacon',
#   'minyak',
#   'kentang goreng',
#   'brownis',
#   'pancake',
#   'laos',
#   'teh hijau'],
#  ['udang',
#   'spageti',
#   'air mineral',
#   'sup',
#   'susu',
#   'minyak zaitun',
#   'ayam',
#   'kue',
#   'burger sauce',
#   'minyak'],
#  ['ayam', 'minyak goreng', 'tea'],
#  ['burger',
#   'sup',
#   'sayuran',
#   'pancake',
#   'deodoran',
#   'semangka',
#   'snack berprotein',
#   'asparagus',
#   'mayones',
#   'mint',
#   'teh hijau'],
#  ['udang', 'merica'],
#  ['spageti', 'minyak zaitun', 'anggur merah'],
#  ['muffin'],
#  ['keju parut', 'rempah-rempah', 'muffin', 'telur', 'susu yogurt'],
#  ['keju parut',
#   'sayuran beku',
#   'spageti',
#   'susu',
#   'gom arab',
#   'krim ',
#   'minyak goreng',
#   'snack rendah gula'],
#  ['merica', 'pancake', 'kentang goreng', 'jus tomat'],
#  ['sayuran beku',
#   'tomat',
#   'keju parmesan',
#   'daging sapi giling',
#   'saus tomat',
#   'susu',
#   'cokelat hitam',
#   'semangka',
#   'mint',
#   'teh hijau'],
#  ['minyak zaitun', 'ayam', 'cokelat', 'biskuit', 'teh hijau'],
#  ['pasta gandum',
#   'daging sapi giling',
#   'spageti',
#   'cokelat',
#   'minyak ikan',
#   'pancake',
#   'telur',
#   'minuman rasa',
#   'sandwich',
#   'jus tomat'],
#  ['telur', 'keju kemasan'],
#  ['muffin', 'keju kemasan'],
#  ['teh hijau', 'minuman rasa', 'minuman beralkohol'],
#  ['air mineral', 'cokelat', 'beras', 'kecap asin'],
#  ['air mineral'],
#  ['udang', 'pasta gandum', 'bakso', 'susu'],
#  ['rempah-rempah',
#   'keju parmesan',
#   'daging sapi giling',
#   'merica',
#   'spageti',
#   'cream',
#   'teh hitam',
#   'almond',
#   'minyak ikan',
#   'pancake',
#   'telur'],
#  ['keju parut',
#   'udang',
#   'keju parmesan',
#   'daging sapi giling',
#   'air mineral',
#   'mint'],
#  ['air mineral', 'beras'],
#  ['pancake'],
#  ['air mineral', 'madu'],
#  ['burger', 'daging sapi giling', 'pancake', 'garam'],
#  ['keju parmesan', 'soda', 'kentang goreng', 'brownis'],
#  ['tepung beras'],
#  ['daging sapi giling',
#   'spageti',
#   'ayam',
#   'beras',
#   'minyak',
#   'minyak goreng',
#   'hotdog',
#   'mint'],
#  ['mentega', 'cokelat'],
#  ['merica'],
#  ['rempah-rempah', 'cokelat', 'kecap asin', 'yogurt kue', 'teh hijau'],
#  ['keju parut', 'air mineral', 'telur', 'daging tanpa tulang'],
#  ['biskuit', 'yogurt kue', 'mayones ringan', 'teh hijau'],
#  ['susu', 'minyak goreng'],
#  ['susu',
#   'minyak zaitun',
#   'krim ',
#   'minyak goreng',
#   'ayam',
#   'cokelat hitam',
#   'sereal',
#   'kentang goreng',
#   'minuman rasa',
#   'pancake',
#   'jus tomat',
#   'roti',
#   'susu yogurt'],
#  ['tomat',
#   'sup',
#   'alpukat',
#   'susu',
#   'yogurt kue',
#   'minuman berenergi',
#   'susu yogurt',
#   'teh hijau'],
#  ['daging sapi', 'cokelat', 'daging sapi giling', 'air mineral', 'minyak'],
#  ['teh hijau', 'kecap asin', 'daging tanpa tulang'],
#  ['cokelat'],
#  ['daging tanpa tulang', 'pasta'],
#  ['burger',
#   'air mineral',
#   'minyak zaitun',
#   'beras',
#   'minuman bervitamin',
#   'minuman rasa'],
#  ['teh hijau'],
#  ['keju parut',
#   'saus tomat',
#   'spageti',
#   'susu',
#   'pancake',
#   'minuman berenergi',
#   'minuman beralkohol'],
#  ['bebek', 'spageti', 'keju tua', 'stroberi'],
#  ['muffin'],
#  ['daging sapi giling', 'spageti', 'cider', 'minyak goreng', 'biskuit'],
#  ['burger',
#   'sayuran beku',
#   'keju parmesan',
#   'spageti',
#   'fromage blanc',
#   'sayuran',
#   'pancake',
#   'madu',
#   'hotdog',
#   'susu yogurt'],
#  ['daging sapi giling'],
#  ['kacang polong'],
#  ['sayuran beku',
#   'air mineral',
#   'madu',
#   'tepung beras',
#   'kecap asin',
#   'daging tanpa tulang'],
#  ['keju parmesan',
#   'susu',
#   'mentega',
#   'teh hitam',
#   'telur',
#   'minuman rasa',
#   'mayones ringan',
#   'sampo',
#   'susu yogurt',
#   'teh hijau'],
#  ['air mineral', 'kue'],
#  ['bebek',
#   'air mineral',
#   'susu',
#   'pancake',
#   'tepung beras',
#   'minyak goreng',
#   'minuman rasa',
#   'biskuit',
#   'teh hijau'],
#  ['alpukat', 'cokelat', 'kentang goreng'],
#  ['teh hijau'],
#  ['cokelat', 'telur', 'semprotan nyamuk'],
#  ['keju parut', 'muffin', 'kentang goreng', 'deodoran'],
#  ['air mineral', 'telur', 'anggur merah', 'soda', 'daging tanpa tulang'],
#  ['tepung beras'],
#  ['nonfat susu', 'biskuit', 'saus krim jamur'],
#  ['kentang goreng', 'kecap asin'],
#  ['air mineral', 'salmon'],
#  ['minyak zaitun'],
#  ['bebek',
#   'tomat',
#   'daging sapi giling',
#   'sup',
#   'susu',
#   'mentega',
#   'madu',
#   'kue',
#   'mint teh hijau',
#   'brownis',
#   'garam'],
#  ['keju parmesan',
#   'spageti',
#   'air mineral',
#   'cokelat',
#   'napkins',
#   'susu yogurt'],
#  ['burger',
#   'keju parmesan',
#   'cokelat',
#   'sup',
#   'susu',
#   'minyak zaitun',
#   'snack batangan',
#   'mentega',
#   'almond',
#   'fromage blanc',
#   'telur',
#   'kue',
#   'pancake'],
#  ['udang', 'madu', 'pasta', 'minuman berenergi', 'teh hijau'],
#  ['tuna segar',
#   'cokelat',
#   'susu',
#   'minyak ikan',
#   'muffin',
#   'pancake',
#   'kecap asin',
#   'minuman rasa'],
#  ['stroberi'],
#  ['rempah-rempah'],
#  ['rempah-rempah',
#   'sayuran beku',
#   'tomat',
#   'keju parmesan',
#   'daging sapi giling',
#   'fromage blanc',
#   'telur',
#   'madu',
#   'kue',
#   'beras',
#   'sereal',
#   'kentang goreng',
#   'kecap asin'],
#  ['spageti',
#   'air mineral',
#   'susu',
#   'keju tua',
#   'sereal',
#   'daging tanpa tulang',
#   'keju kemasan'],
#  ['bebek',
#   'burger',
#   'tuna segar',
#   'spageti',
#   'pancake',
#   'telur',
#   'kue',
#   'keju kemasan',
#   'minuman berenergi',
#   'snack rendah gula'],
#  ['terong'],
#  ['burger',
#   'spageti',
#   'air mineral',
#   'almond',
#   'madu',
#   'cokelat hitam',
#   'wortel',
#   'kentang tumbuk'],
#  ['cokelat',
#   'kentang goreng',
#   'minuman rasa',
#   'keju kemasan',
#   'stroberi',
#   'mayones ringan'],
#  ['keju tua'],
#  ['cokelat', 'kentang goreng'],
#  ['cokelat', 'kentang goreng', 'stroberi'],
#  ['bebek',
#   'sayuran beku',
#   'alpukat',
#   'kue',
#   'krim ',
#   'minyak goreng',
#   'ayam',
#   'cokelat bread',
#   'kentang tumbuk'],
#  ['minyak zaitun', 'snack batangan', 'bawang merah'],
#  ['bebek', 'udang'],
#  ['cokelat', 'spageti', 'kecap asin', 'yogurt kue'],
#  ['udang',
#   'air mineral',
#   'cokelat',
#   'alpukat',
#   'mentega',
#   'laos',
#   'teh hijau'],
#  ['muffin', 'teh hijau', 'brownis'],
#  ['yogurt kue'],
#  ['bebek',
#   'saus tomat',
#   'susu',
#   'mentega',
#   'bacon',
#   'salmon',
#   'minyak goreng',
#   'cokelat',
#   'kentang goreng',
#   'hotdog',
#   'semangka',
#   'snack berprotein',
#   'mint'],
#  ['keju parut'],
#  ['mentega', 'burger sauce', 'brownis', 'pancake'],
#  ['mentega',
#   'pancake',
#   'tepung beras',
#   'teh hijau',
#   'kentang goreng',
#   'biskuit',
#   'bawang merah',
#   'susu yogurt'],
#  ['udang', 'cokelat', 'mentega', 'minyak goreng', 'daging tanpa tulang'],
#  ['burger',
#   'saus tiram',
#   'sayuran beku',
#   'merica',
#   'spageti',
#   'cokelat',
#   'susu',
#   'madu',
#   'tepung beras',
#   'minyak goreng',
#   'sereal'],
#  ['bebek',
#   'daging sapi giling',
#   'spageti',
#   'pancake',
#   'telur',
#   'kue',
#   'cabe',
#   'makanan binatang',
#   'cokelat'],
#  ['udang', 'susu', 'mentega', 'ayam', 'garam', 'mayones', 'teh hijau'],
#  ['tuna segar',
#   'air mineral',
#   'fromage blanc',
#   'madu',
#   'gom arab',
#   'cokelat',
#   'kentang goreng',
#   'minuman rasa',
#   'minuman soda',
#   'stroberi',
#   'teh hijau'],
#  ['cokelat', 'biskuit'],
#  ['minuman soda', 'mayones ringan'],
#  ['sayuran beku',
#   'tomat',
#   'spageti',
#   'ayam',
#   'kentang goreng',
#   'daging tanpa tulang'],
#  ['bebek',
#   'burger',
#   'mentega',
#   'sayuran',
#   'anggur hijau',
#   'pancake',
#   'telur',
#   'kue',
#   'saus BBQ',
#   'teh hijau'],
#  ['saus tiram', 'udang', 'ragi', 'telur', 'burger sauce', 'yogurt kue'],
#  ['kentang goreng', 'mayones ringan'],
#  ['burger', 'daging sapi giling', 'telur', 'cokelat', 'kecap asin', 'laos'],
#  ['saus krim jamur'],
#  ['mentega', 'mint teh hijau'],
#  ['tepung beras'],
#  ['gom arab'],
#  ['air mineral', 'kentang goreng', 'kecap asin', 'teh hijau'],
#  ['sereal', 'garam', 'teh hijau'],
#  ['udang',
#   'spageti',
#   'cokelat',
#   'kentang goreng',
#   'daging tanpa tulang',
#   'biskuit',
#   'brownis',
#   'pancake',
#   'semangka'],
#  ['daging sapi',
#   'spageti',
#   'ragi',
#   'ayam',
#   'minyak goreng',
#   'cokelat',
#   'hotdog'],
#  ['telur'],
#  ['daging sapi giling',
#   'minyak zaitun',
#   'semprotan nyamuk',
#   'minuman rasa',
#   'hotdog'],
#  ['sayuran beku',
#   'spageti',
#   'air mineral',
#   'sup',
#   'minyak zaitun',
#   'daging tanpa tulang'],
#  ['tepung beras', 'minyak', 'ayam', 'kentang goreng', 'daging tanpa tulang'],
#  ['teh hijau'],
#  ['keju parmesan', 'tepung beras', 'daging tanpa tulang', 'kecap asin'],
#  ['tuna segar',
#   'sayuran beku',
#   'ayam',
#   'fromage blanc',
#   'madu',
#   'mayones ringan'],
#  ['daging sapi giling'],
#  ['muffin', 'kecap asin', 'biskuit', 'roti', 'teh hijau'],
#  ['sayuran beku', 'spageti', 'cokelat', 'daging tanpa tulang', 'roti'],
#  ['acar', 'spageti', 'kentang goreng', 'minuman rasa'],
#  ['alpukat'],
#  ['sandwich'],
#  ['spageti', 'susu', 'minyak', 'sampo'],
#  ['kecap asin'],
#  ['spageti'],
#  ['kecap asin'],
#  ['alpukat', 'susu', 'mentega', 'kentang goreng', 'biskuit'],
#  ['bebek',
#   'sayuran beku',
#   'ayam',
#   'telur',
#   'minuman rasa',
#   'brokoli',
#   'susu yogurt'],
#  ['burger',
#   'udang',
#   'tomat',
#   'susu',
#   'snack batangan',
#   'almond',
#   'ayam',
#   'cokelat',
#   'kentang goreng',
#   'deodoran'],
#  ['burger',
#   'susu',
#   'kue',
#   'minyak goreng',
#   'kentang goreng',
#   'daging tanpa tulang',
#   'laos'],
#  ['tomat',
#   'spageti',
#   'cokelat',
#   'susu',
#   'minyak zaitun',
#   'tepung beras',
#   'kue',
#   'minuman rasa',
#   'snack berprotein'],
#  ['tuna segar',
#   'saus tiram',
#   'merica',
#   'spageti',
#   'fromage blanc',
#   'salmon',
#   'pancake',
#   'telur',
#   'madu',
#   'teh hijau'],
#  ['susu', 'susu yogurt'],
#  ['udang', 'keju parmesan', 'sup', 'cokelat', 'brownis'],
#  ['spageti', 'ayam'],
#  ['keju parut', 'sayuran', 'nonfat susu', 'teh hijau'],
#  ['tuna segar', 'keju parmesan', 'cider', 'muffin', 'bayam', 'madu', 'minyak'],
#  ['kue'],
#  ['udang', 'cokelat', 'saus krim jamur', 'snack batangan'],
#  ['snack batangan'],
#  ['alpukat', 'madu'],
#  ['udang', 'sayuran beku', 'tomat', 'keju kemasan'],
#  ['kentang goreng'],
#  ['stroberi'],
#  ['daging sapi giling', 'almond', 'kentang goreng', 'daging tanpa tulang'],
#  ['keju parut', 'spageti'],
#  ['bebek', 'air mineral', 'mentega', 'minuman rasa'],
#  ['sayuran beku', 'spageti', 'kentang goreng', 'mayones ringan', 'teh hijau'],
#  ['burger',
#   'daging sapi',
#   'spageti',
#   'tepung beras',
#   'terong',
#   'cokelat',
#   'biskuit',
#   'bawang merah',
#   'teh hijau'],
#  ['keju parut',
#   'sayuran beku',
#   'spageti',
#   'alpukat',
#   'susu',
#   'anggur merah',
#   'krim ',
#   'beras',
#   'teh hijau',
#   'cokelat',
#   'kentang goreng',
#   'minuman rasa',
#   'biskuit',
#   'hotdog'],
#  ['burger', 'udang', 'tomat', 'bacon', 'tepung beras', 'teh hijau'],
#  ['keju parmesan', 'pancake'],
#  ['keju parmesan', 'kue', 'hotdog', 'teh hijau'],
#  ['spageti',
#   'susu',
#   'fromage blanc',
#   'kecap manis',
#   'cokelat',
#   'makanan bayi'],
#  ['mint'],
#  ['cokelat', 'mint'],
#  ['mentega', 'kentang goreng', 'garam', 'roti'],
#  ['cokelat', 'kentang goreng', 'stroberi', 'yogurt kue', 'mayones ringan'],
#  ['telur', 'terong', 'biskuit'],
#  ['yogurt kue'],
#  ['rempah-rempah',
#   'spageti',
#   'bakso',
#   'susu',
#   'minyak zaitun',
#   'ayam',
#   'madu',
#   'minuman rasa',
#   'daging tanpa tulang',
#   'pancake'],
#  ['sayuran beku', 'beras', 'cokelat'],
#  ['rempah-rempah',
#   'daging sapi giling',
#   'spageti',
#   'cokelat',
#   'susu',
#   'telur',
#   'krim '],
#  ['telur', 'kecap asin'],
#  ['pasta gandum',
#   'daging sapi giling',
#   'minyak zaitun',
#   'anggur merah',
#   'daging tanpa tulang'],
#  ['burger',
#   'saus tiram',
#   'air mineral',
#   'telur',
#   'minyak',
#   'wortel',
#   'snack berprotein',
#   'jus tomat'],
#  ['cokelat',
#   'keju parut',
#   'rempah-rempah',
#   'air mineral',
#   'sup',
#   'minyak zaitun'],
#  ['burger',
#   'udang',
#   'air mineral',
#   'ayam',
#   'fromage blanc',
#   'salmon',
#   'telur',
#   'kue',
#   'minuman rasa',
#   'stroberi'],
#  ['teh hijau'],
#  ['biskuit'],
#  ['kentang goreng', 'biskuit'],
#  ['susu', 'mentega', 'telur'],
#  ['telur', 'saus krim jamur', 'susu yogurt'],
#  ['telur', 'teh hijau'],
#  ['air mineral', 'tepung beras'],
#  ['udang',
#   'sayuran beku',
#   'keju parmesan',
#   'air mineral',
#   'tepung beras',
#   'kue'],
#  ['tepung beras', 'pancake'],
#  ['sayuran beku',
#   'spageti',
#   'minyak zaitun',
#   'mentega',
#   'salmon',
#   'minyak',
#   'minyak goreng',
#   'minuman rasa',
#   'brokoli'],
#  ['teh hijau'],
#  ['tuna segar', 'telur', 'daging tanpa tulang', 'stroberi'],
#  ['spageti', 'sup', 'susu', 'wortel', 'cokelat'],
#  ['burger', 'air mineral', 'sup', 'bakso', 'minyak zaitun'],
#  ['keju parut',
#   'air mineral',
#   'minyak goreng',
#   'kentang goreng',
#   'biskuit',
#   'susu yogurt'],
#  ['udang', 'susu', 'minyak zaitun', 'kentang goreng'],
#  ['sayuran beku', 'air mineral', 'pancake', 'kue', 'jus tomat'],
#  ['spageti', 'susu', 'ayam'],
#  ['keju parut',
#   'air mineral',
#   'ayam',
#   'kentang goreng',
#   'keju kemasan',
#   'pancake'],
#  ['daging sapi giling', 'air mineral', 'susu', 'telur', 'mint'],
#  ['udang', 'deodoran', 'teh hijau'],
#  ['minuman rasa'],
#  ['rempah-rempah', 'sayuran beku', 'air mineral', 'muffin', 'sereal'],
#  ['bebek',
#   'tomat',
#   'spageti',
#   'susu',
#   'cider',
#   'telur',
#   'madu',
#   'kue',
#   'teh hijau',
#   'kentang goreng',
#   'brownis',
#   'jus tomat'],
#  ...]

# %%
# Membuat variabel items yang berisikan transaksi yang tidak terduplikasi  
items = list()
for t in transaksi:
    for x in t:
        if(not x in items):
            items.append(x)
items
# Out:
# ['udang',
#  'almond',
#  'alpukat',
#  'sayuran',
#  'anggur hijau',
#  'gandum',
#  'ragi',
#  'keju kemasan',
#  'minuman berenergi',
#  'jus tomat',
#  'susu yogurt',
#  'teh hijau',
#  'madu',
#  'salad',
#  'air mineral',
#  'salmon',
#  'minuman bervitamin',
#  'minuman rasa',
#  'bayam',
#  'minyak zaitun',
#  'burger',
#  'bakso',
#  'telur',
#  'kacang mete',
#  'bebek',
#  'susu',
#  'snack batangan',
#  'tepung beras',
#  'pasta gandum',
#  'kentang goreng',
#  'sup',
#  'krim ',
#  'bawang merah',
#  'sayuran beku',
#  'spageti',
#  'makanan binatang',
#  'biskuit',
#  'minyak goreng',
#  'kecap asin',
#  'cokelat',
#  'ayam',
#  'minyak',
#  'tuna segar',
#  'tomat',
#  'teh hitam',
#  'cokelat hitam',
#  'snack berprotein',
#  'saus tiram',
#  'pasta',
#  'merica',
#  'sampo',
#  'beras',
#  'minuman soda',
#  'daging sapi',
#  'deodoran',
#  'pancake',
#  'keju parut',
#  'minuman beralkohol',
#  'pasta gigi',
#  'keju parmesan',
#  'roti',
#  'daging sapi giling',
#  'daging tanpa tulang',
#  'rempah-rempah',
#  'saus tomat',
#  'majalah',
#  'stroberi',
#  'keju tua',
#  'acar',
#  'kue',
#  'hotdog',
#  'brownis',
#  'sereal',
#  'aksesoris pakaian',
#  'semprotan nyamuk',
#  'muffin',
#  'mayones ringan',
#  'gom arab',
#  'soda',
#  'cider',
#  'corn',
#  'yogurt kue',
#  'mint',
#  'mentega',
#  'asparagus',
#  'minyak ikan',
#  'garam',
#  'tea',
#  'saus BBQ',
#  'mayones',
#  'laos',
#  'wortel',
#  'saus krim jamur',
#  'cabe',
#  'kentang tumbuk',
#  'nonfat susu',
#  'semprotan air',
#  'cokelat bread',
#  'mint teh hijau',
#  'terong',
#  'anggur merah',
#  'bacon',
#  'fromage blanc',
#  'snack rendah gula',
#  'minuman dessert',
#  'kemiri',
#  'sandwich',
#  'makanan bayi',
#  'semangka',
#  'brokoli',
#  'kacang polong',
#  'kecap manis',
#  'bramble',
#  'burger sauce',
#  'oatmeal',
#  ' asparagus',
#  'cream',
#  'napkins']

# %%
# Membuat list bernama eclat yang merupakan pasangan 2 item, dengan nilai support awal nol (0)
eclat = list()
for i in range(0, len(items)):
    for j in range(i+1, len(items)):
        eclat.append([(items[i],items[j]),0])
Hasil_eclat
# Out:
#                             rule  support
# 0                (udang, almond)        0
# 4611   (merica, minuman dessert)        0
# 4609     (merica, fromage blanc)        0
# 4608             (merica, bacon)        0
# 4607      (merica, anggur merah)        0
# ...                          ...      ...
# 2298  (bakso, aksesoris pakaian)        0
# 2297             (bakso, sereal)        0
# 2296            (bakso, brownis)        0
# 2295             (bakso, hotdog)        0
# 6902            (cream, napkins)        0
#
# [6903 rows x 2 columns]

# %%
# Menghitung nilai support untuk setiap pasangan 2 item
for p in eclat:
    for t in transaksi:
        if(p[0][0] in t) and (p[0][1] in t):
            p[1] += 1
    p[1] = p[1]/len(transaksi)

# %%
# Merubah hasil eclat ke dalam data frame dan mengurutkannya berdasarkan nilai support tertinggi
Hasil_eclat = pd.DataFrame(eclat, columns = ['rule','support']).sort_values(by = 'support', ascending = False)
Hasil_eclat
# Out:
#                                    rule   support
# 1566             (air mineral, spageti)  0.059733
# 1571             (air mineral, cokelat)  0.052667
# 1554               (air mineral, telur)  0.050933
# 1557                (air mineral, susu)  0.048000
# 1593  (air mineral, daging sapi giling)  0.040933
# ...                                 ...       ...
# 4651                  (sampo, gom arab)  0.000000
# 4647         (sampo, aksesoris pakaian)  0.000000
# 4640                  (sampo, stroberi)  0.000000
# 4632                (sampo, pasta gigi)  0.000000
# 6902                   (cream, napkins)  0.000000
#
# [6903 rows x 2 columns]
